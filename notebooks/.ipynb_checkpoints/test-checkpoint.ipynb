# %%
import requests
import geopandas as gpd

# %%
url = 'https://raw.githubusercontent.com/geohacker/india/master/state/india_telengana.geojson'
req_data = requests.get(url=url)
req_json = req_data.json()['features']

# %%
gdf = gpd.read_file(filename=url)

# %%
gdf.boundary.plot()
# Out:
# <AxesSubplot:>

# %%
# gdf.to_file('C:\\Users\\tapal\\OneDrive\\Desktop\\Sameer-Work\\geo-learn\\Indian_Railways\\data\\shape_files\\states')

# %%
gdf = gpd.read_file('C:\\Users\\tapal\\OneDrive\\Desktop\\Sameer-Work\\geo-learn\\Indian_Railways\\data\\shape_files\\IND_states')

# %%
gdf.boundary.plot()
# Out:
# <AxesSubplot:>
